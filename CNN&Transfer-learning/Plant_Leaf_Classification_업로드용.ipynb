# %% [markdown]
# # PART 04. 작물 잎 사진으로 질병 분류하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# !unzip "/content/drive/MyDrive/dataset.zip" -d "/content/drive/MyDrive/dataset/"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (618).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (790).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (392).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (486).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1359).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (205).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1018).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (148).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (107).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (459).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (589).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (734).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (775).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1532).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1159).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (927).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (877).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (848).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1255).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1378).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (686).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (139).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (454).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1554).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1608).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1178).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (782).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (57).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1611).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1383).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1363).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1418).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (767).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (726).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1424).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (638).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1559).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1218).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (225).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (899).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (479).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (127).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (168).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (754).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (717).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1082).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (24).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1027).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1062).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (947).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (906).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (868).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1578).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1322).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (118).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (159).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (208).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (474).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (818).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (83).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1587).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1567).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (4).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (746).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1618).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1624).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (658).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (793).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1482).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (245).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1393).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1462).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (147).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (588).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (106).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (737).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (774).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1286).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1266).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (967).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (926).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1341).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1000).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1526).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1445).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (138).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (179).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (228).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1384).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1141).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (96).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1092).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1364).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (917).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1033).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (838).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (72).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (785).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1184).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1164).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1044).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (887).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1505).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (766).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (709).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (678).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1597).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (265).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1400).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (126).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (167).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (716).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (757).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (601).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (33).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (905).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (946).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (45).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (496).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1541).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1492).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1200).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (215).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (158).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1645).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (599).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (117).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (248).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1433).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1476).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1296).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1137).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (937).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (858).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1306).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1351).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1237).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (14).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (489).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1010).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1272).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (696).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1455).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1244).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1394).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1079).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1151).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1102).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (729).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (792).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1370).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (484).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1194).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (207).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1054).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (105).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (146).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1600).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (736).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (777).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1170).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1515).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (621).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1146).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (925).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (966).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (235).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (137).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (178).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (79).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (268).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1410).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (916).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (957).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1479).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1551).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1502).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (878).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1210).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (784).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (218).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1279).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (749).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (708).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (189).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1316).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1570).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (227).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1254).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (125).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (166).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (756).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1112).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (641).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (904).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (945).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (255).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (598).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (116).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (157).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (688).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1610).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1327).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (936).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (977).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1156).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1427).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1123).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (238).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (2).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1223).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (86).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (728).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (769).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1085).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1512).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (795).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (62).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1026).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1065).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (247).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (897).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (104).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (145).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (776).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (719).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (661).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (924).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (965).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (275).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (136).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (177).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (611).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1523).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (915).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (956).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (23).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1623).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1389).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (787).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (258).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1369).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (805).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (403).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1189).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (748).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1169).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1333).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (499).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (188).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1285).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1265).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (267).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1003).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1584).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (165).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (124).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (888).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1564).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1444).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (739).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (603).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (903).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (944).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (494).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1095).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1328).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (217).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (36).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (115).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (156).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1032).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1071).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (48).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1128).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (631).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1047).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (976).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (935).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1589).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1342).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (309).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1569).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (278).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (69).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (825).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (423).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (768).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (95).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1403).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1537).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (794).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1399).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1107).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (201).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (71).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1637).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (987).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1207).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (144).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (103).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1375).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (718).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (759).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1199).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1644).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1432).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (623).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (199).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1471).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (964).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (923).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1295).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1528).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1175).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (237).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1236).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (135).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (176).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1013).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1594).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1271).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (52).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (651).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1454).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (914).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (955).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1078).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (786).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1546).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (698).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (329).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1334).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (845).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (443).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (285).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1057).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1134).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (187).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1599).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1352).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (13).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (221).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (123).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (164).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (738).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (779).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (643).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1413).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (902).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (943).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1117).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (257).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (155).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (114).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1478).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (204).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1217).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (671).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (934).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (975).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1278).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (308).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (349).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (865).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (463).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (797).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1556).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (241).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (986).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (815).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (143).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (413).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (758).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (663).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (59).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (198).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (288).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1381).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (963).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (922).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1361).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (277).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1485).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1426).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (134).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (175).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (224).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1465).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (898).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1181).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (613).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1161).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (954).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (913).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1222).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (328).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (369).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1084).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (26).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1029).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (803).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1064).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (401).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1320).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (186).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (319).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (261).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (40).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (835).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1120).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (433).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (163).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (778).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (605).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (85).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (901).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (942).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1581).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (211).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1561).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (997).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (61).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (113).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (154).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1303).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (244).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1622).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (633).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (974).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (933).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1429).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1391).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (789).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (348).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1495).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1284).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1229).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1191).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1264).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (823).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (421).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1347).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1002).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1520).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (796).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1447).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (339).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (681).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (203).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1143).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (98).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1094).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (985).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (503).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (855).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (453).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1243).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (295).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (806).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1035).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (74).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1070).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (625).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (197).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1186).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (921).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (962).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1166).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1046).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (231).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1507).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (133).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (174).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (264).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (653).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1607).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (912).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (953).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (600).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1629).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1591).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1402).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (214).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (368).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1313).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1575).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (843).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (35).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (441).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1636).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (47).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1543).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (287).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1206).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1339).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (185).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1643).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (359).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (318).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (408).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1470).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (223).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1294).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1139).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (523).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (875).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (473).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1235).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1357).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1304).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (16).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (826).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (645).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1012).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1270).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (941).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (900).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1457).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (251).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1534).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1153).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1104).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (996).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (153).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (206).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1253).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (673).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1376).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (298).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (932).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (973).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1196).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (620).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1348).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1056).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (788).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1172).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (234).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1517).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (863).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (461).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1148).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (51).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1617).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1539).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1412).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (379).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (338).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (428).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (243).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (543).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (984).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (502).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (813).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (411).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (846).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1553).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1216).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (665).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (196).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (920).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (961).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (271).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1021).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (173).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (226).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (615).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1314).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1572).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (911).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (952).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (640).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1548).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (254).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1114).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (801).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (184).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1358).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (799).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (358).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (448).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (263).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1325).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (833).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (522).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (563).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (431).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1484).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1158).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (866).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1421).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (607).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1464).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (940).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1125).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (213).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (691).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (995).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (513).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1221).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (88).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (246).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (816).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1087).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (635).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1028).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (64).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (931).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (972).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (1067).JPG
#   inflating: /content/drive/MyDrive/dataset/Apple___healthy/image (660).JPG
# ...
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (323).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1022).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1061).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1538).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (587).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (457).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2173).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (351).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (310).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (400).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (882).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2286).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2230).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (609).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1723).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2273).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (564).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1552).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1817).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2000).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2076).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (170).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (908).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1527).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (949).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (432).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2141).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1627).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1385).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (239).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (514).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (555).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (684).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1365).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (3).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (850).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1481).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2184).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1422).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (290).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2132).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1461).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1185).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2044).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (445).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1165).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (700).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1281).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (302).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (343).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1226).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (181).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1261).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (394).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1088).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1068).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (477).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1952).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (330).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (371).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1091).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (420).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1324).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (629).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (32).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2093).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2200).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (44).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (590).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1124).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (282).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (928).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (969).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1043).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1881).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (452).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1822).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1861).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (259).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (89).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (534).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (575).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1737).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1681).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (870).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (65).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1307).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (386).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (919).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1661).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2244).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (91).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1407).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1988).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (465).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1488).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2102).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2022).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (720).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1968).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2061).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (322).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1395).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (363).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1848).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1103).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1468).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2178).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (809).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1491).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1203).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1288).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1371).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1195).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (586).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (415).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1268).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1436).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1475).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1006).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (791).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (313).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (350).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (440).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1291).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2197).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (649).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (192).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1171).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1443).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2146).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1232).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2297).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1147).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1985).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1098).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1746).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1965).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (948).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1247).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2011).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1039).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (472).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (78).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1074).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (279).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (554).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1330).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1503).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (939).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2165).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1053).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1891).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1603).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1130).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1688).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1771).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (703).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (740).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2226).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (342).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2261).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1668).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (180).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2055).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (829).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1691).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (397).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1924).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1317).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1571).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (2068).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1843).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (39).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (435).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1632).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1417).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1998).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1675).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1498).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (333).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (370).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (460).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1858).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1113).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (669).JPG
#   inflating: /content/drive/MyDrive/dataset/Peach___Bacterial_spot/image (1439).JPG

# %% [markdown]
# ## 패키지 로드

# %%
import os
import shutil
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision import models
from torchvision.datasets import ImageFolder
import time
import copy

# %% [markdown]
# ## 데이터 분할

# %% [markdown]
# * 데이터 분할을 위한 디렉토리 생성

# %%
original_dataset_dir = '/content/drive/MyDrive/dataset'
classes_list = os.listdir(original_dataset_dir)

base_dir = '/content/drive/MyDrive/splitted'
try:
    os.mkdir(base_dir)
except:
    pass

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')
try:
    os.mkdir(train_dir)
    os.mkdir(validation_dir)
    os.mkdir(test_dir)
except:
    pass

for cls in classes_list:
    try:
        os.mkdir(os.path.join(train_dir, cls))
        os.mkdir(os.path.join(validation_dir, cls))
        os.mkdir(os.path.join(test_dir, cls))
    except:
        pass

# %% [markdown]
# * 데이터 분할과 클래스별 데이터 수 확인

# %%
for cls in classes_list:
    path = os.path.join(original_dataset_dir, cls)
    fnames = os.listdir(path)

    # train:validation:test = 6:2:2 split
    train_size = math.floor(len(fnames) * 0.6)
    validation_size = math.floor(len(fnames) * 0.2)
    test_size = math.floor(len(fnames) * 0.2)

    train_fnames = fnames[:train_size]
    print("Train size(",cls,"): ", len(train_fnames))
    for fname in train_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(train_dir, cls), fname)
        shutil.copyfile(src, dst)

    validation_fnames = fnames[train_size:(validation_size + train_size)]
    print("Validation size(",cls,"): ", len(validation_fnames))
    for fname in validation_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(validation_dir, cls), fname)
        shutil.copyfile(src, dst)

    test_fnames = fnames[(train_size+validation_size):(validation_size + train_size +test_size)]

    print("Test size(",cls,"): ", len(test_fnames))
    for fname in test_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(test_dir, cls), fname)
        shutil.copyfile(src, dst)
# Out:
# Train size( Pepper,_bell___healthy ):  886
# Validation size( Pepper,_bell___healthy ):  295
# Test size( Pepper,_bell___healthy ):  295
# Train size( Grape___Esca_(Black_Measles) ):  829
# Validation size( Grape___Esca_(Black_Measles) ):  276
# Test size( Grape___Esca_(Black_Measles) ):  276
# Train size( Pepper,_bell___Bacterial_spot ):  598
# Validation size( Pepper,_bell___Bacterial_spot ):  199
# Test size( Pepper,_bell___Bacterial_spot ):  199
# Train size( Strawberry___healthy ):  273
# Validation size( Strawberry___healthy ):  91
# Test size( Strawberry___healthy ):  91
# Train size( Grape___Black_rot ):  708
# Validation size( Grape___Black_rot ):  236
# Test size( Grape___Black_rot ):  236
# Train size( Corn___Common_rust ):  715
# Validation size( Corn___Common_rust ):  238
# Test size( Corn___Common_rust ):  238
# Train size( Apple___Apple_scab ):  378
# Validation size( Apple___Apple_scab ):  126
# Test size( Apple___Apple_scab ):  126
# Train size( Potato___healthy ):  91
# Validation size( Potato___healthy ):  30
# Test size( Potato___healthy ):  30
# Train size( Potato___Late_blight ):  600
# Validation size( Potato___Late_blight ):  200
# Test size( Potato___Late_blight ):  200
# Train size( Cherry___healthy ):  512
# Validation size( Cherry___healthy ):  170
# Test size( Cherry___healthy ):  170
# Train size( Tomato___Bacterial_spot ):  1276
# Validation size( Tomato___Bacterial_spot ):  425
# Test size( Tomato___Bacterial_spot ):  425
# Train size( Apple___Black_rot ):  372
# Validation size( Apple___Black_rot ):  124
# Test size( Apple___Black_rot ):  124
# Train size( Cherry___Powdery_mildew ):  631
# Validation size( Cherry___Powdery_mildew ):  210
# Test size( Cherry___Powdery_mildew ):  210
# Train size( Corn___Cercospora_leaf_spot Gray_leaf_spot ):  307
# Validation size( Corn___Cercospora_leaf_spot Gray_leaf_spot ):  102
# Test size( Corn___Cercospora_leaf_spot Gray_leaf_spot ):  102
# Train size( Peach___healthy ):  216
# Validation size( Peach___healthy ):  72
# Test size( Peach___healthy ):  72
# Train size( Tomato___Early_blight ):  600
# Validation size( Tomato___Early_blight ):  200
# Test size( Tomato___Early_blight ):  200
# Train size( Tomato___Tomato_Yellow_Leaf_Curl_Virus ):  3214
# Validation size( Tomato___Tomato_Yellow_Leaf_Curl_Virus ):  1071
# Test size( Tomato___Tomato_Yellow_Leaf_Curl_Virus ):  1071
# Train size( Grape___Leaf_blight_(Isariopsis_Leaf_Spot) ):  645
# Validation size( Grape___Leaf_blight_(Isariopsis_Leaf_Spot) ):  215
# Test size( Grape___Leaf_blight_(Isariopsis_Leaf_Spot) ):  215
# Train size( Potato___Early_blight ):  600
# Validation size( Potato___Early_blight ):  200
# Test size( Potato___Early_blight ):  200
# Train size( Grape___healthy ):  253
# Validation size( Grape___healthy ):  84
# Test size( Grape___healthy ):  84
# Train size( Apple___Cedar_apple_rust ):  165
# Validation size( Apple___Cedar_apple_rust ):  55
# Test size( Apple___Cedar_apple_rust ):  55
# Train size( Corn___Northern_Leaf_Blight ):  591
# Validation size( Corn___Northern_Leaf_Blight ):  197
# Test size( Corn___Northern_Leaf_Blight ):  197
# Train size( Tomato___Septoria_leaf_spot ):  1062
# Validation size( Tomato___Septoria_leaf_spot ):  354
# Test size( Tomato___Septoria_leaf_spot ):  354
# Train size( Corn___healthy ):  697
# Validation size( Corn___healthy ):  232
# Test size( Corn___healthy ):  232
# Train size( Strawberry___Leaf_scorch ):  665
# Validation size( Strawberry___Leaf_scorch ):  221
# Test size( Strawberry___Leaf_scorch ):  221
# Train size( Tomato___Tomato_mosaic_virus ):  223
# Validation size( Tomato___Tomato_mosaic_virus ):  74
# Test size( Tomato___Tomato_mosaic_virus ):  74
# Train size( Tomato___Leaf_Mold ):  571
# Validation size( Tomato___Leaf_Mold ):  190
# Test size( Tomato___Leaf_Mold ):  190
# Train size( Tomato___Late_blight ):  1145
# Validation size( Tomato___Late_blight ):  381
# Test size( Tomato___Late_blight ):  381
# Train size( Tomato___healthy ):  954
# Validation size( Tomato___healthy ):  318
# Test size( Tomato___healthy ):  318
# Train size( Tomato___Spider_mites Two-spotted_spider_mite ):  1005
# Validation size( Tomato___Spider_mites Two-spotted_spider_mite ):  335
# Test size( Tomato___Spider_mites Two-spotted_spider_mite ):  335
# Train size( Apple___healthy ):  987
# Validation size( Apple___healthy ):  329
# Test size( Apple___healthy ):  329
# Train size( Tomato___Target_Spot ):  842
# Validation size( Tomato___Target_Spot ):  280
# Test size( Tomato___Target_Spot ):  280
# Train size( Peach___Bacterial_spot ):  1378
# Validation size( Peach___Bacterial_spot ):  459
# Test size( Peach___Bacterial_spot ):  459

# %% [markdown]
# ## 베이스라인 모델 학습

# %% [markdown]
# * 베이스라인 모델 학습을 위한 준비

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
BATCH_SIZE = 256
EPOCH = 15

# %%
transform_base = transforms.Compose([transforms.Resize((64,64)), transforms.ToTensor()])
train_dataset = ImageFolder(root='/content/drive/MyDrive/splitted/train', transform=transform_base)
val_dataset = ImageFolder(root='/content/drive/MyDrive/splitted/val', transform=transform_base)

# %%
#train_loader, val_loader 정의
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

# %% [markdown]
# * 베이스라인 모델 설계하기

# %%
class Net(nn.Module):

    #사전 모델 정의
    def __init__(self):

        super(Net, self).__init__()

        #nn.Conv2d(input channel수, output channel수, filter크기)
        #convolution층을 적층할 때, 연쇄적으로! (ex. conv1에서 output channel수가 32였으면 conv2의 input channel수도 32)
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 64, 3, padding=1)

        self.fc1 = nn.Linear(4096, 512)
        self.fc2 = nn.Linear(512, 33) #분류할 클래스 총 33개

    #중요부분 (실제로 어떻게 모델을 구성할지)
    def forward(self, x):

        x = self.conv1(x) # 앞서 정의한 conv1층 적용
        x = F.relu(x) # ReLU함수 적용
        x = self.pool(x) # MaxPooling 적용
        x = F.dropout(x, p = 0.25, training = self.training)

        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p = 0.25, training = self.training)

        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p = 0.25, training = self.training)


        x = x.view(-1,4096)
        x = self.fc1(x)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.fc2(x)

        return F.log_softmax(x, dim=1)

model_base = Net().to(DEVICE)
optimizer = optim.Adam(model_base.parameters(), lr=0.001)

# %% [markdown]
# * 모델 학습을 위한 함수

# %%
#중요 부분
def train(model, train_loader, optimizer):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE)

        optimizer.zero_grad() # gradient를 0으로 초기화
        output = model(data)
        loss = F.cross_entropy(output, target) # cross-entropy loss 계산 (output은 모델에 들어가서 예측한 값, target은 실제 정답(label))
        loss.backward() # 오차 역전파 수행
        optimizer.step() # 최적화 (모델 파라미터 업데이트)

# %% [markdown]
# * 모델 평가를 위한 함수

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)

            test_loss += F.cross_entropy(output,target, reduction='sum').item()


            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %% [markdown]
# * 모델 학습을 실행하기

# %%
def train_baseline(model ,train_loader, val_loader, optimizer, num_epochs = 30):
    best_acc = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())

    #중요 부분
    for epoch in range(1, num_epochs + 1):
        since = time.time()
        train(model, train_loader, optimizer)
        train_loss, train_acc = evaluate(model, train_loader)
        val_loss, val_acc = evaluate(model, val_loader)

        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict()) #여기까지

        time_elapsed = time.time() - since
        print('-------------- epoch {} ----------------'.format(epoch))
        print('train Loss: {:.4f}, Accuracy: {:.2f}%'.format(train_loss, train_acc))
        print('val Loss: {:.4f}, Accuracy: {:.2f}%'.format(val_loss, val_acc))
        print('Completed in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    model.load_state_dict(best_model_wts)
    return model


base = train_baseline(model_base, train_loader, val_loader, optimizer, EPOCH)
torch.save(base,'baseline.pt')
# Out:
# -------------- epoch 1 ----------------
# train Loss: 1.5140, Accuracy: 57.26%
# val Loss: 1.5253, Accuracy: 56.82%
# Completed in 2m 8s
# -------------- epoch 2 ----------------
# train Loss: 1.0299, Accuracy: 69.40%
# val Loss: 1.0567, Accuracy: 67.72%
# Completed in 2m 6s
# -------------- epoch 3 ----------------
# train Loss: 0.7872, Accuracy: 75.54%
# val Loss: 0.8213, Accuracy: 74.45%
# Completed in 1m 58s
# -------------- epoch 4 ----------------
# train Loss: 0.5535, Accuracy: 82.73%
# val Loss: 0.5987, Accuracy: 80.62%
# Completed in 1m 58s
# -------------- epoch 5 ----------------
# train Loss: 0.4775, Accuracy: 85.17%
# val Loss: 0.5309, Accuracy: 83.20%
# Completed in 1m 57s
# -------------- epoch 6 ----------------
# train Loss: 0.3957, Accuracy: 87.92%
# val Loss: 0.4632, Accuracy: 85.03%
# Completed in 1m 57s
# -------------- epoch 7 ----------------
# train Loss: 0.3428, Accuracy: 89.63%
# val Loss: 0.4132, Accuracy: 86.72%
# Completed in 1m 58s
# -------------- epoch 8 ----------------
# train Loss: 0.3159, Accuracy: 90.70%
# val Loss: 0.3935, Accuracy: 87.08%
# Completed in 1m 59s
# -------------- epoch 9 ----------------
# train Loss: 0.2587, Accuracy: 92.32%
# val Loss: 0.3427, Accuracy: 88.78%
# Completed in 2m 1s
# -------------- epoch 10 ----------------
# train Loss: 0.2721, Accuracy: 91.73%
# val Loss: 0.3660, Accuracy: 87.96%
# Completed in 1m 58s
# -------------- epoch 11 ----------------
# train Loss: 0.2372, Accuracy: 92.84%
# val Loss: 0.3280, Accuracy: 89.42%
# Completed in 1m 56s
# -------------- epoch 12 ----------------
# train Loss: 0.1940, Accuracy: 94.17%
# val Loss: 0.2882, Accuracy: 90.81%
# Completed in 1m 59s
# -------------- epoch 13 ----------------
# train Loss: 0.1991, Accuracy: 94.01%
# val Loss: 0.3060, Accuracy: 89.96%
# Completed in 1m 59s
# -------------- epoch 14 ----------------
# train Loss: 0.1633, Accuracy: 95.28%
# val Loss: 0.2707, Accuracy: 91.20%
# Completed in 1m 58s
# -------------- epoch 15 ----------------
# train Loss: 0.1470, Accuracy: 95.61%
# val Loss: 0.2551, Accuracy: 91.73%
# Completed in 1m 56s

# %% [markdown]
# ## Transfer Learning 모델 학습

# %% [markdown]
# * Transfer Learning을 위한 준비

# %%
data_transforms = {
    'train': transforms.Compose([transforms.Resize([64,64]),
        transforms.RandomHorizontalFlip(), transforms.RandomVerticalFlip(),
        transforms.RandomCrop(52), transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) ]),

    'val': transforms.Compose([transforms.Resize([64,64]),
        transforms.RandomCrop(52), transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) ])
}

# %%
data_dir = '/content/drive/MyDrive/splitted'
image_datasets = {x: ImageFolder(root=os.path.join(data_dir, x), transform=data_transforms[x]) for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=BATCH_SIZE, shuffle=True, num_workers=2) for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

class_names = image_datasets['train'].classes

# %% [markdown]
# * Pre-Trained Model 불러오기

# %%
#중요 부분(resnet pre-trained model을 앞서 이용하고 마지막 fc layer부분만 task에 맞게 33으로 바꾸기)

resnet = models.resnet18(pretrained=True) #resnet18 (pre-trained model) 불러와서 pretrained weight 가져오기
num_ftrs = resnet.fc.in_features
resnet.fc = nn.Linear(num_ftrs, 33) #resnet의 입력 특성수인 num_ftrs를 이 분류 task에 맞게 33개로 바꾸기 (fine tuning)
resnet = resnet.to(DEVICE)

criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, resnet.parameters()), lr=0.001)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 159MB/s]

# %% [markdown]
# * Pre-Trained Model의 일부 Layer Freeze하기

# %%
ct = 0
for child in resnet.children():
    ct += 1
    if ct < 6:
        for param in child.parameters():
            param.requires_grad = False #초반 5개의 층은 gradient update가 안되게 하여 가중치 고정시키기(freeze)

# %% [markdown]
# * Transfer Learning 모델 학습과 검증을 위한 함수

# %%
def train_resnet(model, criterion, optimizer, scheduler, num_epochs=25):

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('-------------- epoch {} ----------------'.format(epoch+1))
        since = time.time()
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0


            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss/dataset_sizes[phase]
            epoch_acc = running_corrects.double()/dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))


            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        time_elapsed = time.time() - since
        print('Completed in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    model.load_state_dict(best_model_wts)

    return model

# %% [markdown]
# * 모델 학습을 실행하기

# %%
model_resnet = train_resnet(resnet, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=EPOCH)

torch.save(model_resnet, 'resnet.pt')
# Out:
# -------------- epoch 1 ----------------
# train Loss: 0.6127 Acc: 0.8110
# val Loss: 0.3269 Acc: 0.8901
# Completed in 1m 17s
# -------------- epoch 2 ----------------
# train Loss: 0.2408 Acc: 0.9197
# val Loss: 0.3367 Acc: 0.8929
# Completed in 1m 15s
# -------------- epoch 3 ----------------
# train Loss: 0.1689 Acc: 0.9435
# val Loss: 0.1930 Acc: 0.9383
# Completed in 1m 19s
# -------------- epoch 4 ----------------
# train Loss: 0.1473 Acc: 0.9517
# val Loss: 0.2031 Acc: 0.9385
# Completed in 1m 17s
# -------------- epoch 5 ----------------
# train Loss: 0.1227 Acc: 0.9593
# val Loss: 0.1583 Acc: 0.9473
# Completed in 1m 15s
# -------------- epoch 6 ----------------
# train Loss: 0.1247 Acc: 0.9585
# val Loss: 0.1610 Acc: 0.9457
# Completed in 1m 16s
# -------------- epoch 7 ----------------
# train Loss: 0.0964 Acc: 0.9670
# val Loss: 0.1168 Acc: 0.9636
# Completed in 1m 19s
# -------------- epoch 8 ----------------
# train Loss: 0.0536 Acc: 0.9826
# val Loss: 0.0676 Acc: 0.9771
# Completed in 1m 15s
# -------------- epoch 9 ----------------
# train Loss: 0.0382 Acc: 0.9877
# val Loss: 0.0610 Acc: 0.9790
# Completed in 1m 26s
# -------------- epoch 10 ----------------
# train Loss: 0.0334 Acc: 0.9887
# val Loss: 0.0634 Acc: 0.9795
# Completed in 1m 22s
# -------------- epoch 11 ----------------
# train Loss: 0.0312 Acc: 0.9895
# val Loss: 0.0555 Acc: 0.9817
# Completed in 1m 27s
# -------------- epoch 12 ----------------
# train Loss: 0.0255 Acc: 0.9918
# val Loss: 0.0531 Acc: 0.9821
# Completed in 1m 19s
# -------------- epoch 13 ----------------
# train Loss: 0.0257 Acc: 0.9913
# val Loss: 0.0488 Acc: 0.9835
# Completed in 1m 23s
# -------------- epoch 14 ----------------
# train Loss: 0.0227 Acc: 0.9925
# val Loss: 0.0579 Acc: 0.9811
# Completed in 1m 25s
# -------------- epoch 15 ----------------
# train Loss: 0.0202 Acc: 0.9940
# val Loss: 0.0506 Acc: 0.9830
# Completed in 1m 16s
# Best val Acc: 0.983477

# %% [markdown]
# ## 모델 평가

# %% [markdown]
# * 베이스라인 모델 평가를 위한 전처리하기

# %%
transform_base = transforms.Compose([transforms.Resize([64,64]),transforms.ToTensor()])
test_base = ImageFolder(root='/content/drive/MyDrive/splitted/test',transform=transform_base)
test_loader_base = torch.utils.data.DataLoader(test_base, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

# %% [markdown]
# * Transfer Learning모델 평가를 위한 전처리하기

# %%
transform_resNet = transforms.Compose([
        transforms.Resize([64,64]),
        transforms.RandomCrop(52),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

test_resNet = ImageFolder(root='/content/drive/MyDrive/splitted/test', transform=transform_resNet)
test_loader_resNet = torch.utils.data.DataLoader(test_resNet, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

# %% [markdown]
# * 베이스라인 모델 성능 평가하기

# %%
baseline=torch.load('baseline.pt')
baseline.eval()
test_loss, test_accuracy = evaluate(baseline, test_loader_base)

print('baseline test acc:  ', test_accuracy)
# Out:
# baseline test acc:   91.82626110902491

# %% [markdown]
# * Transfer Learning 모델 성능 평가하기

# %%
resnet=torch.load('resnet.pt')
resnet.eval()
test_loss, test_accuracy = evaluate(resnet, test_loader_resNet)

print('ResNet test acc:  ', test_accuracy)
# Out:
# ResNet test acc:   98.38527975966954
